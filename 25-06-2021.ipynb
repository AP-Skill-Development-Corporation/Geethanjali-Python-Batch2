# %%
n=int(input())
l_v=input()
l_v=l_v.split()[:n]
l_v=list(map(int,l_v))
print(l_v)
# Out:
# 5
# 10 20 30 40 50 60 70 80
# [10, 20, 30, 40, 50]

# %%
n=int(input())
l_v=list(map(int,input().split()[:n]))
s_d=''
for value in l_v:
    last=value%10
    s_d=s_d+str(last)
if int(s_d)%10==0:
    print("yes")
else:
    print("No")
# Out:
# 47650
# ...

# %%
import pandas

# %%
print(dir(pandas))
# Out:
# ['Categorical', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'ExcelFile', 'ExcelWriter', 'Expr', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int64Index', 'Interval', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Period', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseSeries', 'Term', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt64Index', 'WidePanel', '_DeprecatedModule', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p10', '_np_version_under1p11', '_np_version_under1p12', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_tslib', '_version', 'api', 'bdate_range', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'datetime', 'datetools', 'describe_option', 'errors', 'eval', 'factorize', 'get_dummies', 'get_o
# ...

# %%
import numpy

# %%
print(len(dir(numpy)))
# Out:
# 623

# %%
# Data Series
series=pandas.Series([10,20,30,40,50])
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
series[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd

# %%
print(len(pd.date_range(start="06-25-2021",end="06-30-2021")))
# Out:
# 6

# %%
data=pd.Series([102,104,105,105,405,607],pd.date_range(start="06-25-2021",end="06-30-2021"))
print(data)
# Out:
# 2021-06-25    102
# 2021-06-26    104
# 2021-06-27    105
# 2021-06-28    105
# 2021-06-29    405
# 2021-06-30    607
# Freq: D, dtype: int64

# %%
#Data Frame ->rows and columns
df=pd.DataFrame([['vijay',"Sai","Manoj"],[25,26,27],['Nokia','samsung','apple'],['vizag','HYD','Vijayawada']])
print(df.columns)
print(df.values)
df
# Out:
# RangeIndex(start=0, stop=3, step=1)
# [['vijay' 'Sai' 'Manoj']
#  [25 26 27]
#  ['Nokia' 'samsung' 'apple']
#  ['vizag' 'HYD' 'Vijayawada']]
#        0        1           2
# 0  vijay      Sai       Manoj
# 1     25       26          27
# 2  Nokia  samsung       apple
# 3  vizag      HYD  Vijayawada

# %%
df[1]
# Out:
# 0        Sai
# 1         26
# 2    samsung
# 3        HYD
# Name: 1, dtype: object

# %%
df.columns=['col1','col2','col3']

# %%
df
# Out:
#     col1     col2        col3
# 0  vijay      Sai       Manoj
# 1     25       26          27
# 2  Nokia  samsung       apple
# 3  vizag      HYD  Vijayawada

# %%
df['col1']
# Out:
# 0    vijay
# 1       25
# 2    Nokia
# 3    vizag
# Name: col1, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index=['names','ages','phones','places']

# %%
df
# Out:
#          col1     col2        col3
# names   vijay      Sai       Manoj
# ages       25       26          27
# phones  Nokia  samsung       apple
# places  vizag      HYD  Vijayawada

# %%
df['names':'ages']
# Out:
#         col1 col2   col3
# names  vijay  Sai  Manoj
# ages      25   26     27

# %%
df.loc['ages']
# Out:
# col1    25
# col2    26
# col3    27
# Name: ages, dtype: object

# %%
df['col1']
# Out:
# names     vijay
# ages         25
# phones    Nokia
# places    vizag
# Name: col1, dtype: object

# %%
df
# Out:
#          col1     col2        col3
# names   vijay      Sai       Manoj
# ages       25       26          27
# phones  Nokia  samsung       apple
# places  vizag      HYD  Vijayawada

# %%
df.iloc[3,1]
# Out:
# 'HYD'

# %%
# https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv

df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
df
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df.shape
# Out:
# (979, 6)

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
df.values
# Out:
# array([[9.3, 'The Shawshank Redemption', 'R', 'Crime', 142,
#         "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"],
#        [9.2, 'The Godfather', 'R', 'Crime', 175,
#         "[u'Marlon Brando', u'Al Pacino', u'James Caan']"],
#        [9.1, 'The Godfather: Part II', 'R', 'Crime', 200,
#         "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"],
#        ...,
#        [7.4, 'Master and Commander: The Far Side of the World', 'PG-13',
#         'Action', 138,
#         "[u'Russell Crowe', u'Paul Bettany', u'Billy Boyd']"],
#        [7.4, 'Poltergeist', 'PG', 'Horror', 114,
#         '[u\'JoBeth Williams\', u"Heather O\'Rourke", u\'Craig T. Nelson\']'],
#        [7.4, 'Wall Street', 'R', 'Crime', 126,
#         "[u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']"]],
#       dtype=object)

# %%
df.values[1]
# Out:
# array([9.2, 'The Godfather', 'R', 'Crime', 175,
#        "[u'Marlon Brando', u'Al Pacino', u'James Caan']"], dtype=object)

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df[df['star_rating']>9.0]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df[df['star_rating']>8.0]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df[df['star_rating']>9.0]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df[(df['star_rating']>9.0) & (df['star_rating']>8.0)]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
print(df[df['genre']=="Crime"].count())
print(df[df['genre']=="Comedy"].count())
print(df[df['genre']=="Action"].count())
# Out:
# star_rating       124
# title             124
# content_rating    124
# genre             124
# duration          124
# actors_list       124
# dtype: int64
# star_rating       156
# title             156
# content_rating    156
# genre             156
# duration          156
# actors_list       156
# dtype: int64
# star_rating       136
# title             136
# content_rating    135
# genre             136
# duration          136
# actors_list       136
# dtype: int64

# %%
df[(df['star_rating']>7.5) & (df['genre']=="Action")]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
# http://bit.ly/movieusers
# https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user
Salary=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user',sep='|')
Salary.columns=["sn.no",'age','gender','designation','salary']

# %%
Salary
# Out:
#      sn.no  age gender    designation salary
# 0        2   53      F          other  94043
# 1        3   23      M         writer  32067
# 2        4   24      M     technician  43537
# 3        5   33      F          other  15213
# 4        6   42      M      executive  98101
# 5        7   57      M  administrator  91344
# 6        8   36      M  administrator  05201
# 7        9   29      M        student  01002
# 8       10   53      M         lawyer  90703
# 9       11   39      F          other  30329
# 10      12   28      F          other  06405
# 11      13   47      M       educator  29206
# 12      14   45      M      scientist  55106
# 13      15   49      F       educator  97301
# 14      16   21      M  entertainment  10309
# 15      17   30      M     programmer  06355
# 16      18   35      F          other  37212
# 17      19   40      M      librarian  02138
# 18      20   42      F      homemaker  95660
# 19      21   26      M         writer  30068
# ...

# %%
Salary.isnull().sum()
# Out:
# sn.no          0
# age            0
# gender         0
# designation    0
# salary         0
# dtype: int64

# %%
Salary[Salary.isnull()]
# Out:
#      sn.no  age gender designation salary
# 0      NaN  NaN    NaN         NaN    NaN
# 1      NaN  NaN    NaN         NaN    NaN
# 2      NaN  NaN    NaN         NaN    NaN
# 3      NaN  NaN    NaN         NaN    NaN
# 4      NaN  NaN    NaN         NaN    NaN
# 5      NaN  NaN    NaN         NaN    NaN
# 6      NaN  NaN    NaN         NaN    NaN
# 7      NaN  NaN    NaN         NaN    NaN
# 8      NaN  NaN    NaN         NaN    NaN
# 9      NaN  NaN    NaN         NaN    NaN
# 10     NaN  NaN    NaN         NaN    NaN
# 11     NaN  NaN    NaN         NaN    NaN
# 12     NaN  NaN    NaN         NaN    NaN
# 13     NaN  NaN    NaN         NaN    NaN
# 14     NaN  NaN    NaN         NaN    NaN
# 15     NaN  NaN    NaN         NaN    NaN
# 16     NaN  NaN    NaN         NaN    NaN
# 17     NaN  NaN    NaN         NaN    NaN
# 18     NaN  NaN    NaN         NaN    NaN
# 19     NaN  NaN    NaN         NaN    NaN
# 20     NaN  NaN    NaN         NaN    NaN
# ...

# %%
Salary
# Out:
#      sn.no  age gender    designation salary
# 0        2   53      F          other  94043
# 1        3   23      M         writer  32067
# 2        4   24      M     technician  43537
# 3        5   33      F          other  15213
# 4        6   42      M      executive  98101
# 5        7   57      M  administrator  91344
# 6        8   36      M  administrator  05201
# 7        9   29      M        student  01002
# 8       10   53      M         lawyer  90703
# 9       11   39      F          other  30329
# 10      12   28      F          other  06405
# 11      13   47      M       educator  29206
# 12      14   45      M      scientist  55106
# 13      15   49      F       educator  97301
# 14      16   21      M  entertainment  10309
# 15      17   30      M     programmer  06355
# 16      18   35      F          other  37212
# 17      19   40      M      librarian  02138
# 18      20   42      F      homemaker  95660
# 19      21   26      M         writer  30068
# ...

# %%
Salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 5 columns):
# sn.no          942 non-null int64
# age            942 non-null int64
# gender         942 non-null object
# designation    942 non-null object
# salary         942 non-null object
# dtypes: int64(2), object(3)
# memory usage: 36.9+ KB

# %%
Salary[Salary['age']>70]
# Out:
#      sn.no  age gender designation salary
# 479    481   73      M     retired  37771
